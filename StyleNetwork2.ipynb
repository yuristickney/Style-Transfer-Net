# %%
from keras.preprocessing.image import load_img, img_to_array

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
target_image_path  = r'Y:\Documents\StyleNetwork\City_1.jpg'
style_reference_image_path = r'Y:\Documents\StyleNetwork\Graphic_1.jpg'
generated_image_path = r'Y:\Documents\StyleNetwork\Space_1.jpg'

# %%
width, height = load_img(target_image_path).size
width, height
# Out:
# (1500, 969)

# %%
img_height  = 400
img_width = int(width * img_height / height)
img_width
# Out:
# 619

# %%
import  numpy  as  np
from keras.applications import  vgg19

# %%
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_height, img_width))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# %%
def deprocess_image(x):
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
from keras import backend as K

target_image = K.constant(preprocess_image(target_image_path))
style_reference_image = K.constant(preprocess_image(style_reference_image_path))

# This placeholder will contain our generated image
combination_image = K.placeholder((1, img_height, img_width, 3))

# We combine the 3 images into a single batch
input_tensor = K.concatenate([target_image, style_reference_image, combination_image], axis=0)

# %%
# We build the VGG19 network with our batch of 3 images as input.
# The model will be loaded with pre-trained ImageNet weights.
model = vgg19.VGG19(input_tensor=input_tensor, weights='imagenet', include_top=False)
print('vgg Model loaded.')
# Out:
# vgg Model loaded.

# %%
def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
def gram_matrix(x):
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

def style_loss(style, combination):
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_height * img_width
    return K.sum(K.square(S - C)) / (4. * (channels ** 2) * (size ** 2))

# %%
def total_variation_loss(x):
    a = K.square(x[:, :img_height - 1, :img_width - 1, :] - x[:, 1:, :img_width - 1, :])
    b = K.square(x[:, :img_height - 1, :img_width - 1, :] - x[:, :img_height - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %%
for layer in model.layers:
    if 'pool' not in str(layer.name):
        print("'" + layer.name + "',")
# Out:
# 'input_7',
# 'block1_conv1',
# 'block1_conv2',
# 'block2_conv1',
# 'block2_conv2',
# 'block3_conv1',
# 'block3_conv2',
# 'block3_conv3',
# 'block3_conv4',
# 'block4_conv1',
# 'block4_conv2',
# 'block4_conv3',
# 'block4_conv4',
# 'block5_conv1',
# 'block5_conv2',
# 'block5_conv3',
# 'block5_conv4',

# %%
# Dict mapping layer names to activation tensors
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# Name of layer used for content loss
content_layer = 'block2_conv2'
# Name of layers used for style loss
'''
style_layers = ['block1_conv1',
                'block1_conv2',
                'block2_conv1',
                'block2_conv2',
                'block3_conv1',
                'block3_conv2',
                'block3_conv3',
                'block3_conv4',
                'block4_conv1',
                'block4_conv2',
                'block4_conv3',
                'block4_conv4',
                'block5_conv1',
                'block5_conv2',
                'block5_conv3',
                'block5_conv4']
'''

style_layers = ['block1_conv2',
                'block2_conv2',
                'block3_conv4',
                'block4_conv4',
                'block5_conv4']

# Weights in the weighted average of the loss components
total_variation_weight = 1e-4
style_weight = 1.
content_weight = 0.05

# Define the loss by adding all components to a `loss` variable
loss = K.variable(0.)
layer_features = outputs_dict[content_layer]
target_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss += content_weight * content_loss(target_image_features, combination_features)


for layer_name in style_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss += (style_weight / len(style_layers)) * sl
    
    
loss += total_variation_weight * total_variation_loss(combination_image)

# %%
grads = K.gradients (loss, combination_image)

outputs = [loss]
outputs += grads

model_func = K.function([combination_image], outputs)
model_func

# %%
# Get the gradients of the generated image wrt the loss
grads = K.gradients(loss, combination_image)[0]

# Function to fetch the values of the current loss and the current gradients
fetch_loss_and_grads = K.function([combination_image], [loss, grads])


class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        x = x.reshape((1, img_height, img_width, 3))
        outs = fetch_loss_and_grads([x])
        loss_value = outs[0]
        grad_values = outs[1].flatten().astype('float64')
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

evaluator = Evaluator()

# %%
from scipy.optimize import fmin_l_bfgs_b
from scipy.misc import imsave
import time

result_prefix = 'style_transfer_result'
iterations = 100

# Run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss.
# This is our initial state: the target image.
# Note that `scipy.optimize.fmin_l_bfgs_b` can only process flat vectors.
x = preprocess_image(generated_image_path)
# x = np.random.uniform(0, 255, (1, img_height, img_width, 3)) - 128.
x = x.flatten()
for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x, fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # Save current generated image
    img = x.copy().reshape((img_height, img_width, 3))
    img = deprocess_image(img)
    fname = result_prefix + '_at_iteration_%d.png' % i
    imsave(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 77072970000.0
# Image saved as style_transfer_result_at_iteration_0.png
# Iteration 0 completed in 62s
# Start of iteration 1
# C:\Users\yuris\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# Current loss value: 61690860000.0
# Image saved as style_transfer_result_at_iteration_1.png
# Iteration 1 completed in 61s
# Start of iteration 2
# Current loss value: 54277180000.0
# Image saved as style_transfer_result_at_iteration_2.png
# Iteration 2 completed in 58s
# Start of iteration 3
# Current loss value: 50090910000.0
# Image saved as style_transfer_result_at_iteration_3.png
# Iteration 3 completed in 56s
# Start of iteration 4
# Current loss value: 47590110000.0
# Image saved as style_transfer_result_at_iteration_4.png
# Iteration 4 completed in 57s
# Start of iteration 5
# Current loss value: 45642244000.0
# Image saved as style_transfer_result_at_iteration_5.png
# Iteration 5 completed in 59s
# Start of iteration 6
# Current loss value: 44013610000.0
# Image saved as style_transfer_result_at_iteration_6.png
# Iteration 6 completed in 58s
# Start of iteration 7
# Current loss value: 42896440000.0
# Image saved as style_transfer_result_at_iteration_7.png
# Iteration 7 completed in 57s
# Start of iteration 8
# Current loss value: 41998080000.0
# Image saved as style_transfer_result_at_iteration_8.png
# Iteration 8 completed in 61s
# Start of iteration 9
# Current loss value: 41284940000.0
# Image saved as style_transfer_result_at_iteration_9.png
# Iteration 9 completed in 56s
# Start of iteration 10
# Current loss value: 40605660000.0
# Image saved as style_transfer_result_at_iteration_10.png
# Iteration 10 completed in 59s
# Start of iteration 11
# Current loss value: 40075424000.0
# Image saved as style_transfer_result_at_iteration_11.png
# Iteration 11 completed in 55s
# Start of iteration 12
# Current loss value: 39572074000.0
# Image saved as style_transfer_result_at_iteration_12.png
# Iteration 12 completed in 56s
# Start of iteration 13
# Current loss value: 39179067000.0
# Image saved as style_transfer_result_at_iteration_13.png
# Iteration 13 completed in 60s
# Start of iteration 14
# Current loss value: 38896010000.0
# Image saved as style_transfer_result_at_iteration_14.png
# Iteration 14 completed in 60s
# Start of iteration 15
# Current loss value: 38602772000.0
# Image saved as style_transfer_result_at_iteration_15.png
# Iteration 15 completed in 58s
# Start of iteration 16
# Current loss value: 38316487000.0
# Image saved as style_transfer_result_at_iteration_16.png
# Iteration 16 completed in 58s
# Start of iteration 17
# Current loss value: 38076760000.0
# Image saved as style_transfer_result_at_iteration_17.png
# Iteration 17 completed in 57s
# Start of iteration 18
# Current loss value: 37881123000.0
# Image saved as style_transfer_result_at_iteration_18.png
# Iteration 18 completed in 58s
# Start of iteration 19
# Current loss value: 37679186000.0
# Image saved as style_transfer_result_at_iteration_19.png
# Iteration 19 completed in 59s
# Start of iteration 20
# Current loss value: 37496340000.0
# Image saved as style_transfer_result_at_iteration_20.png
# Iteration 20 completed in 61s
# Start of iteration 21
# Current loss value: 37320830000.0
# Image saved as style_transfer_result_at_iteration_21.png
# Iteration 21 completed in 59s
# Start of iteration 22
# Current loss value: 37161070000.0
# Image saved as style_transfer_result_at_iteration_22.png
# Iteration 22 completed in 60s
# Start of iteration 23
# Current loss value: 37020350000.0
# Image saved as style_transfer_result_at_iteration_23.png
# Iteration 23 completed in 59s
# Start of iteration 24
# Current loss value: 36878545000.0
# Image saved as style_transfer_result_at_iteration_24.png
# Iteration 24 completed in 58s
# Start of iteration 25
# Current loss value: 36752474000.0
# Image saved as style_transfer_result_at_iteration_25.png
# Iteration 25 completed in 58s
# Start of iteration 26
# Current loss value: 36641800000.0
# Image saved as style_transfer_result_at_iteration_26.png
# Iteration 26 completed in 57s
# Start of iteration 27
# Current loss value: 36536880000.0
# Image saved as style_transfer_result_at_iteration_27.png
# Iteration 27 completed in 59s
# Start of iteration 28
# Current loss value: 36431962000.0
# Image saved as style_transfer_result_at_iteration_28.png
# Iteration 28 completed in 59s
# Start of iteration 29
# Current loss value: 36333630000.0
# Image saved as style_transfer_result_at_iteration_29.png
# Iteration 29 completed in 59s
# Start of iteration 30
# Current loss value: 36231434000.0
# Image saved as style_transfer_result_at_iteration_30.png
# Iteration 30 completed in 57s
# Start of iteration 31
# Current loss value: 36133330000.0
# Image saved as style_transfer_result_at_iteration_31.png
# Iteration 31 completed in 61s
# Start of iteration 32
# Current loss value: 36048777000.0
# Image saved as style_transfer_result_at_iteration_32.png
# Iteration 32 completed in 59s
# Start of iteration 33
# Current loss value: 35966370000.0
# Image saved as style_transfer_result_at_iteration_33.png
# Iteration 33 completed in 61s
# Start of iteration 34
# Current loss value: 35891778000.0
# Image saved as style_transfer_result_at_iteration_34.png
# Iteration 34 completed in 62s
# Start of iteration 35
# Current loss value: 35822748000.0
# Image saved as style_transfer_result_at_iteration_35.png
# Iteration 35 completed in 59s
# Start of iteration 36
# Current loss value: 35754360000.0
# Image saved as style_transfer_result_at_iteration_36.png
# Iteration 36 completed in 62s
# Start of iteration 37
# Current loss value: 35682836000.0
# Image saved as style_transfer_result_at_iteration_37.png
# Iteration 37 completed in 59s
# Start of iteration 38
# Current loss value: 35620196000.0
# Image saved as style_transfer_result_at_iteration_38.png
# Iteration 38 completed in 59s
# Start of iteration 39
# Current loss value: 35559520000.0
# Image saved as style_transfer_result_at_iteration_39.png
# Iteration 39 completed in 60s
# Start of iteration 40
# Current loss value: 35501662000.0
# Image saved as style_transfer_result_at_iteration_40.png
# Iteration 40 completed in 58s
# Start of iteration 41
# Current loss value: 35445190000.0
# Image saved as style_transfer_result_at_iteration_41.png
# Iteration 41 completed in 57s
# Start of iteration 42
# Current loss value: 35392905000.0
# Image saved as style_transfer_result_at_iteration_42.png
# Iteration 42 completed in 58s
# Start of iteration 43
# Current loss value: 35342390000.0
# Image saved as style_transfer_result_at_iteration_43.png
# Iteration 43 completed in 59s
# Start of iteration 44
# Current loss value: 35290900000.0
# Image saved as style_transfer_result_at_iteration_44.png
# Iteration 44 completed in 60s
# Start of iteration 45
# Current loss value: 35243580000.0
# Image saved as style_transfer_result_at_iteration_45.png
# Iteration 45 completed in 54s
# Start of iteration 46
# Current loss value: 35200197000.0
# Image saved as style_transfer_result_at_iteration_46.png
# Iteration 46 completed in 59s
# Start of iteration 47
# Current loss value: 35159724000.0
# Image saved as style_transfer_result_at_iteration_47.png
# Iteration 47 completed in 59s
# Start of iteration 48
# Current loss value: 35118920000.0
# Image saved as style_transfer_result_at_iteration_48.png
# Iteration 48 completed in 58s
# Start of iteration 49
# Current loss value: 35080716000.0
# Image saved as style_transfer_result_at_iteration_49.png
# Iteration 49 completed in 59s
# Start of iteration 50
# Current loss value: 35044585000.0
# Image saved as style_transfer_result_at_iteration_50.png
# Iteration 50 completed in 59s
# Start of iteration 51
# Current loss value: 35008233000.0
# Image saved as style_transfer_result_at_iteration_51.png
# Iteration 51 completed in 60s
# Start of iteration 52
# Current loss value: 34975590000.0
# Image saved as style_transfer_result_at_iteration_52.png
# Iteration 52 completed in 59s
# Start of iteration 53
# Current loss value: 34943672000.0
# Image saved as style_transfer_result_at_iteration_53.png
# Iteration 53 completed in 59s
# Start of iteration 54
# Current loss value: 34912883000.0
# Image saved as style_transfer_result_at_iteration_54.png
# Iteration 54 completed in 59s
# Start of iteration 55
# Current loss value: 34883710000.0
# Image saved as style_transfer_result_at_iteration_55.png
# Iteration 55 completed in 59s
# Start of iteration 56
# Current loss value: 34854683000.0
# Image saved as style_transfer_result_at_iteration_56.png
# Iteration 56 completed in 58s
# Start of iteration 57
# Current loss value: 34827362000.0
# Image saved as style_transfer_result_at_iteration_57.png
# Iteration 57 completed in 59s
# Start of iteration 58
# Current loss value: 34800140000.0
# Image saved as style_transfer_result_at_iteration_58.png
# Iteration 58 completed in 60s
# Start of iteration 59
# Current loss value: 34773336000.0
# Image saved as style_transfer_result_at_iteration_59.png
# Iteration 59 completed in 59s
# Start of iteration 60
# Current loss value: 34747930000.0
# Image saved as style_transfer_result_at_iteration_60.png
# Iteration 60 completed in 58s
# Start of iteration 61
# Current loss value: 34724413000.0
# Image saved as style_transfer_result_at_iteration_61.png
# Iteration 61 completed in 60s
# Start of iteration 62
# Current loss value: 34701746000.0
# Image saved as style_transfer_result_at_iteration_62.png
# Iteration 62 completed in 59s
# Start of iteration 63
# Current loss value: 34680218000.0
# Image saved as style_transfer_result_at_iteration_63.png
# Iteration 63 completed in 59s
# Start of iteration 64
# Current loss value: 34660057000.0
# Image saved as style_transfer_result_at_iteration_64.png
# Iteration 64 completed in 63s
# Start of iteration 65
# Current loss value: 34640577000.0
# Image saved as style_transfer_result_at_iteration_65.png
# Iteration 65 completed in 59s
# Start of iteration 66
# Current loss value: 34622490000.0
# Image saved as style_transfer_result_at_iteration_66.png
# Iteration 66 completed in 57s
# Start of iteration 67
# Current loss value: 34605260000.0
# Image saved as style_transfer_result_at_iteration_67.png
# Iteration 67 completed in 56s
# Start of iteration 68
# Current loss value: 34588254000.0
# Image saved as style_transfer_result_at_iteration_68.png
# Iteration 68 completed in 59s
# Start of iteration 69
# Current loss value: 34571153000.0
# Image saved as style_transfer_result_at_iteration_69.png
# Iteration 69 completed in 57s
# Start of iteration 70
# Current loss value: 34555023000.0
# Image saved as style_transfer_result_at_iteration_70.png
# Iteration 70 completed in 59s
# Start of iteration 71
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-158-de67c51a229d> in <module>()
#      16     print('Start of iteration', i)
#      17     start_time = time.time()
# ---> 18     x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x, fprime=evaluator.grads, maxfun=20)
#      19     print('Current loss value:', min_val)
#      20     # Save current generated image
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\scipy\optimize\lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\scipy\optimize\lbfgsb.py in func_and_grad(x)
#     283     else:
#     284         def func_and_grad(x):
# --> 285             f = fun(x, *args)
#     286             g = jac(x, *args)
#     287             return f, g
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     290
#     291     def function_wrapper(*wrapper_args):
# --> 292         ncalls[0] += 1
#     293         return function(*(wrapper_args + args))
#     294
#
# <ipython-input-157-f3131c5968bd> in loss(self, x)
#      15         assert self.loss_value is None
#      16         x = x.reshape((1, img_height, img_width, 3))
# ---> 17         outs = fetch_loss_and_grads([x])
#      18         loss_value = outs[0]
#      19         grad_values = outs[1].flatten().astype('float64')
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
# Content image
plt.imshow(load_img(target_image_path, target_size=(img_height, img_width)))
plt.figure()

# Style image
plt.imshow(load_img(style_reference_image_path, target_size=(img_height, img_width)))
plt.figure()

# Generate image
plt.imshow(img)
plt.show()
